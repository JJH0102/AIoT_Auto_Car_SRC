# %%
# 사진 분류

from pop import AI, Pilot
import numpy as np
import cv2

# %%
IMG_AMOUNT = 30

X_data = []
Y_data = []

for i in range(IMG_AMOUNT):
    img = cv2.imread('../../testimg/' + str(i) + '.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (50, 50), interpolation = cv2.INTER_AREA)
   
    X_data.append(img.reshape(50,50,1).astype(float))
    y = np.loadtxt('../../testimg/' + str(i) + '.txt')
    Y_data.append(y)

# %%
CNN = AI.CNN(input_size = [50, 50], output_size = 2)
CNN.X_data = X_data
CNN.Y_data = Y_data

CNN.train(times = 500)
# Out:
# 10 step loss: 33442.42578125
# 20 step loss: 17799.1328125
# 30 step loss: 106852.40625
# 40 step loss: 68849.015625
# 50 step loss: 16721.53125
# 60 step loss: 1843.25390625
# 70 step loss: 1174.835205078125
# 80 step loss: 373.7518310546875
# 90 step loss: 122.13374328613281
# 100 step loss: 195.6311492919922
# 110 step loss: 366.6158752441406
# 120 step loss: 227.12506103515625
# 130 step loss: 142.2537078857422
# 140 step loss: 19.30118751525879
# 150 step loss: 61.02063751220703
# 160 step loss: 65.59290313720703
# 170 step loss: 87.32563781738281
# 180 step loss: 28.32108497619629
# 190 step loss: 41.748291015625
# 200 step loss: 59.616676330566406
# 210 step loss: 144.24984741210938
# 220 step loss: 38.900386810302734
# 230 step loss: 31.602258682250977
# 240 step loss: 16.22255516052246
# 250 step loss: 38.564029693603516
# 260 step loss: 35.15142059326172
# 270 step loss: 21.58344078063965
# 280 step loss: 24.423418045043945
# 290 step loss: 21.513551712036133
# 300 step loss: 19.077035903930664
# 310 step loss: 64.7744369506836
# 320 step loss: 35.25
# 330 step loss: 53.92219161987305
# 340 step loss: 25.483407974243164
# 350 step loss: 33.74014663696289
# 360 step loss: 42.88467788696289
# 370 step loss: 5.560640335083008
# 380 step loss: 16.969125747680664
# 390 step loss: 10.821596145629883
# 400 step loss: 18.92087173461914
# 410 step loss: 18.179224014282227
# 420 step loss: 6.629992485046387
# 430 step loss: 31.762414932250977
# 440 step loss: 3.388826608657837
# 450 step loss: 23.886960983276367
# 460 step loss: 19.536142349243164
# 470 step loss: 1.7685933113098145
# 480 step loss: 22.68001365661621
# 490 step loss: 24.729007720947266
# 500 step loss: 0.0
# Training is done.
# Time spent: 8.7 s
# Training speed: 57.2 step/s

# %%
CNN.run([CNN.X_data[20]])
# Out:
# array([[1., 0.]], dtype=float32)

# %%
CNN.run([CNN.X_data[11]])
# Out:
# array([[0., 1.]], dtype=float32)

# %%
cam = Pilot.Camera()

# %%
frame = cam.value
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
frame = cv2.resize(frame, (50, 50), interpolation = cv2.INTER_AREA)
CNN.run([frame.reshape(50, 50, 1)])
# Out:
# array([[0., 1.]], dtype=float32)
